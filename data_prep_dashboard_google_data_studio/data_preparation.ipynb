# %% [markdown]
# ### Quick notes about this notebook
# Hi. I want to share my thoughts during this task as much as I can, that's why I decided to write down detailed notes as a go along. I trust it will be helpful.

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Initial attempt to load data

# %%
dataset = pd.read_csv('unsd-citypopulation-year-fm_csv.txt')

# %% [markdown]
# ### Initial exploratory
# First, I will take a look on the size of the data, data completeness and column types

# %%
print(dataset.shape)
print(dataset.dtypes)
dataset.count()
# Out:
# (28528, 11)
# Country or Area    object
# Year               object
# Area               object
# Sex                object
# City               object
# City type          object
# Record Type        object
# Reliability        object
# Source Year        object
# Value              object
# Value Footnotes    object
# dtype: object
# Country or Area    28528
# Year               28528
# Area               28365
# Sex                28365
# City               28365
# City type          28365
# Record Type        28365
# Reliability        28365
# Source Year        28365
# Value              28365
# Value Footnotes     9633
# dtype: int64

# %% [markdown]
# It seens not a huge dataset. I got curious about a few "missing" records (28528 - 28365 = 163), then I tried the following command:

# %%
dataset[dataset['Area'].isnull()].head()
# Out:
#       Country or Area                                               Year Area  \
# 28364   footnoteSeqID                                           Footnote  NaN
# 28365               1      Including armed forces stationed in the area.  NaN
# 28366               2  Data refer to projections based on the 2001 Po...  NaN
# 28367               3  The urban agglomeration of Buenos Aires includ...  NaN
# 28368               4  The urban agglomeration of Tucumán-Tafí Viejo ...  NaN
#
#        Sex City City type Record Type Reliability Source Year Value  \
# 28364  NaN  NaN       NaN         NaN         NaN         NaN   NaN
# 28365  NaN  NaN       NaN         NaN         NaN         NaN   NaN
# 28366  NaN  NaN       NaN         NaN         NaN         NaN   NaN
# 28367  NaN  NaN       NaN         NaN         NaN         NaN   NaN
# 28368  NaN  NaN       NaN         NaN         NaN         NaN   NaN
#
#       Value Footnotes
# 28364             NaN
# 28365             NaN
# 28366             NaN
# 28367             NaN
# 28368             NaN

# %% [markdown]
# After that, just realised there are different headers on this dataset.
#
# I will load the data into different datasets.
#
# I have also seen this weird record, will take care.

# %%
dataset.iloc[28377]
# Out:
# Country or Area                                                   13
# Year               Locations are generally based on Statistical D...
# Area                                                         Proper"
# Sex                                                          usually
# City                                                           based
# City type                                                         on
# Record Type                                                      the
# Reliability                                               city inner
# Source Year                                              Statistical
# Value                                                          Local
# Value Footnotes                                                Area"
# Name: 28377, dtype: object

# %% [markdown]
# ### Loading datasets properly

# %%
dataset1 = pd.read_csv('unsd-citypopulation-year-fm_csv.txt', nrows=28363, encoding='utf_8')
print(dataset1.count())
dataset1.head()
# Out:
# Country or Area    28363
# Year               28363
# Area               28363
# Sex                28363
# City               28363
# City type          28363
# Record Type        28363
# Reliability        28363
# Source Year        28363
# Value              28363
# Value Footnotes     9632
# dtype: int64
#   Country or Area  Year   Area     Sex       City    City type  \
# 0   Åland Islands  2013  Total    Male  MARIEHAMN  City proper
# 1   Åland Islands  2013  Total  Female  MARIEHAMN  City proper
# 2   Åland Islands  2012  Total    Male  MARIEHAMN  City proper
# 3   Åland Islands  2012  Total  Female  MARIEHAMN  City proper
# 4   Åland Islands  2011  Total    Male  MARIEHAMN  City proper
#
#           Record Type             Reliability  Source Year   Value  \
# 0  Estimate - de jure  Final figure, complete         2014  5445.0
# 1  Estimate - de jure  Final figure, complete         2014  5925.0
# 2  Estimate - de jure  Final figure, complete         2013  5408.0
# 3  Estimate - de jure  Final figure, complete         2013  5896.5
# 4  Estimate - de jure  Final figure, complete         2012  5363.5
#
#   Value Footnotes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Load dataset 2, but skip one malformed record
dataset2 = pd.read_csv('unsd-citypopulation-year-fm_csv.txt', skiprows=list(range(0,28365)) + [28378], encoding='utf_8')
dataset2 = dataset2[['footnoteSeqID', 'Footnote']]

# Work around the malformed record 
Footnote = list(dataset.iloc[28377])[1:]
Footnote = ' '.join(Footnote)
footnoteSeqID = int(list(dataset.iloc[28377])[0])
missing_record = pd.DataFrame(data={'footnoteSeqID': [footnoteSeqID], 'Footnote': [Footnote]})

# Add the missing record
dataset2 = pd.concat([dataset2, missing_record], axis=0)

# Check data
print(dataset2.count())
dataset2.head()
# Out:
# footnoteSeqID    163
# Footnote         163
# dtype: int64
#    footnoteSeqID                                           Footnote
# 0              1      Including armed forces stationed in the area.
# 1              2  Data refer to projections based on the 2001 Po...
# 2              3  The urban agglomeration of Buenos Aires includ...
# 3              4  The urban agglomeration of Tucumán-Tafí Viejo ...
# 4              5             Data refer to private households only.

# %% [markdown]
# ### Mapping Value Footnotes

# %%
# Create a dictionary of footnotes
dict_of_footnotes = dict(dataset2.values)
dict_of_footnotes[-1] = "No comment has been added for this entry"

# Replace null values
dataset1['Value Footnotes'] = np.where(dataset1['Value Footnotes'].isnull(), '-1', dataset1['Value Footnotes'])

# Separeta all Value Footnotes in a Array os strings
array_footnotes_aux = dataset1['Value Footnotes'].values

# Convert from array of strings to array of array
array_footnotes = [x.split(',') for x in array_footnotes_aux]

# Map from id => description
res = []
for v in array_footnotes:
    new = [dict_of_footnotes[int(i)] for i in v if int(i) in dict_of_footnotes.keys()]
    if new == []:
        new = ['There was a note, but it was not present in the lookup table {}'.format(v)]
    res = res + [new]
    
# Enrich dataset1
dataset1['notes'] = res

dataset1.head()
# Out:
#   Country or Area  Year   Area     Sex       City    City type  \
# 0   Åland Islands  2013  Total    Male  MARIEHAMN  City proper
# 1   Åland Islands  2013  Total  Female  MARIEHAMN  City proper
# 2   Åland Islands  2012  Total    Male  MARIEHAMN  City proper
# 3   Åland Islands  2012  Total  Female  MARIEHAMN  City proper
# 4   Åland Islands  2011  Total    Male  MARIEHAMN  City proper
#
#           Record Type             Reliability  Source Year   Value  \
# 0  Estimate - de jure  Final figure, complete         2014  5445.0
# 1  Estimate - de jure  Final figure, complete         2014  5925.0
# 2  Estimate - de jure  Final figure, complete         2013  5408.0
# 3  Estimate - de jure  Final figure, complete         2013  5896.5
# 4  Estimate - de jure  Final figure, complete         2012  5363.5
#
#   Value Footnotes                                       notes
# 0              -1  [No comment has been added for this entry]
# 1              -1  [No comment has been added for this entry]
# 2              -1  [No comment has been added for this entry]
# 3              -1  [No comment has been added for this entry]
# 4              -1  [No comment has been added for this entry]

# %% [markdown]
# ### Some exploratory work

# %%
print(dataset1.columns)

dataset1['id'] = dataset1.index
aggregations = dict()
aggregations['id'] = 'count'
dataset1.groupby(['Record Type'], as_index=False).agg(aggregations)
# Out:
# Index(['Country or Area', 'Year', 'Area', 'Sex', 'City', 'City type',
#        'Record Type', 'Reliability', 'Source Year', 'Value', 'Value Footnotes',
#        'notes'],
#       dtype='object')
#                                Record Type     id
# 0  Census - de facto - complete tabulation   3441
# 1   Census - de jure - complete tabulation  10004
# 2     Census - de jure - sample tabulation    144
# 3                      Estimate - de facto   1578
# 4                       Estimate - de jure  12902
# 5       Record type not defined/applicable     10
# 6                 Sample survey - de facto    100
# 7                  Sample survey - de jure    184

# %% [markdown]
# #### De jure vs de facto census
# * de jure - according to the regular or legal residence
# * de facto - according to the place where enumerated

# %% [markdown]
# ### Data aggregation and preparation for viz

# %%
dataset1.head()
# Out:
#   Country or Area  Year   Area     Sex       City    City type  \
# 0   Åland Islands  2013  Total    Male  MARIEHAMN  City proper
# 1   Åland Islands  2013  Total  Female  MARIEHAMN  City proper
# 2   Åland Islands  2012  Total    Male  MARIEHAMN  City proper
# 3   Åland Islands  2012  Total  Female  MARIEHAMN  City proper
# 4   Åland Islands  2011  Total    Male  MARIEHAMN  City proper
#
#           Record Type             Reliability  Source Year   Value  \
# 0  Estimate - de jure  Final figure, complete         2014  5445.0
# 1  Estimate - de jure  Final figure, complete         2014  5925.0
# 2  Estimate - de jure  Final figure, complete         2013  5408.0
# 3  Estimate - de jure  Final figure, complete         2013  5896.5
# 4  Estimate - de jure  Final figure, complete         2012  5363.5
#
#   Value Footnotes                                       notes  id
# 0              -1  [No comment has been added for this entry]   0
# 1              -1  [No comment has been added for this entry]   1
# 2              -1  [No comment has been added for this entry]   2
# 3              -1  [No comment has been added for this entry]   3
# 4              -1  [No comment has been added for this entry]   4

# %% [markdown]
# #### First, I will transpose the column "Sex".

# %%
# Tramspose
pivot = pd.pivot_table(dataset1,index=['Country or Area', 'Year', 'Area', 'City', 'City type', 'Record Type', 'Reliability'], \
               columns=['Sex'], \
               values=['Value'], \
               aggfunc=[np.sum])

# Convert pivot view to flat schema
dataset_transposed = pd.DataFrame(pivot.to_records())

# Rename columns
dataset_transposed.columns = ['Country or Area', 'Year', 'Area', 'City', 'City type', 'Record Type', 'Reliability', 'Female', 'Male']
dataset_transposed.head()
# Out:
#   Country or Area  Year   Area              City            City type  \
# 0         Albania  2003  Total            TIRANA          City proper
# 1         Albania  2011  Total            Durrës          City proper
# 2         Albania  2011  Total            TIRANA          City proper
# 3  American Samoa  2000  Total         PAGO PAGO          City proper
# 4         Andorra  2003  Total  ANDORRA LA VELLA  Urban agglomeration
#
#                               Record Type             Reliability    Female  \
# 0                     Estimate - de facto  Final figure, complete  198857.0
# 1  Census - de jure - complete tabulation  Final figure, complete   56738.0
# 2  Census - de jure - complete tabulation  Final figure, complete  215256.0
# 3  Census - de jure - complete tabulation  Final figure, complete    2192.0
# 4                      Estimate - de jure  Final figure, complete   10543.0
#
#        Male
# 0  194006.0
# 1   56511.0
# 2  203239.0
# 3    2086.0
# 4   10702.0

# %% [markdown]
# #### Quick validation

# %%
dataset1[dataset1['City'] == 'TIRANA']
# Out:
#    Country or Area  Year   Area     Sex    City    City type  \
# 17         Albania  2011  Total    Male  TIRANA  City proper
# 19         Albania  2011  Total  Female  TIRANA  City proper
# 20         Albania  2003  Total    Male  TIRANA  City proper
# 21         Albania  2003  Total  Female  TIRANA  City proper
#
#                                Record Type             Reliability  \
# 17  Census - de jure - complete tabulation  Final figure, complete
# 19  Census - de jure - complete tabulation  Final figure, complete
# 20                     Estimate - de facto  Final figure, complete
# 21                     Estimate - de facto  Final figure, complete
#
#     Source Year     Value Value Footnotes  \
# 17         2013  203239.0              -1
# 19         2013  215256.0              -1
# 20         2004  194006.0              -1
# 21         2004  198857.0              -1
#
#                                          notes  id
# 17  [No comment has been added for this entry]  17
# 19  [No comment has been added for this entry]  19
# 20  [No comment has been added for this entry]  20
# 21  [No comment has been added for this entry]  21

# %%
dataset_transposed[dataset_transposed['City'] == 'TIRANA']
# Out:
#   Country or Area  Year   Area    City    City type  \
# 0         Albania  2003  Total  TIRANA  City proper
# 2         Albania  2011  Total  TIRANA  City proper
#
#                               Record Type             Reliability    Female  \
# 0                     Estimate - de facto  Final figure, complete  198857.0
# 2  Census - de jure - complete tabulation  Final figure, complete  215256.0
#
#        Male
# 0  194006.0
# 2  203239.0

# %% [markdown]
# #### Next, I will create period comparissons
# Note: I will not compare YoY because most of times we dont have data for consecutive years. I will compare current census vs prior census (always looking to the same group to keep it fair)

# %%
# Create a new column to store the total number do people, regardless the sex
dataset_transposed['Total'] = dataset_transposed['Female'] + dataset_transposed['Male']

# Data is already aggregate. I will just reorder it
aggregations = dict()
aggregations['Total'] = 'sum'
aggregations['Female'] = 'sum'
aggregations['Male'] = 'sum'
df = dataset_transposed.groupby(['Country or Area', 'City', 'City type', 'Record Type', 'Year'], as_index = False) \
.agg(aggregations) \
.sort_values(['Country or Area', 'City', 'City type', 'Record Type', 'Year'], ascending=[True,True,True,True,True])

# Create a key to compute dense rank
df['key'] = df['Country or Area'] + ' | ' + df['City'] + ' | ' + df['City type'] + ' | ' + df['Record Type'] 

# Compute dense rank based on the key
df['rank'] = df.key.rank(method='dense').astype(int)

# Fetch the prior periods
df['prior_period_total'] = df['Total'].shift()
df['prior_period_female'] = df['Female'].shift()
df['prior_period_male'] = df['Male'].shift()

# Fetch the prior rank for validation
df['prior_rank'] = df['rank'].shift()

# Keep only the prior period from the same groups
df['prior_period_total'] = np.where(df['prior_rank'] == df['rank'], df['prior_period_total'], np.NaN)
df['prior_period_female'] = np.where(df['prior_rank'] == df['rank'], df['prior_period_female'], np.NaN)
df['prior_period_male'] = np.where(df['prior_rank'] == df['rank'], df['prior_period_male'], np.NaN)

# Adjust
df['diff_total'] = np.where( ((df['Total'] > 0) & (df['prior_period_total'] > 0)), ((df['Total'] / df['prior_period_total'])-1), np.NaN)
df['diff_female'] = np.where( ((df['Female'] > 0) & (df['prior_period_female'] > 0)), ((df['Female'] / df['prior_period_female'])-1), np.NaN)
df['diff_male'] = np.where( ((df['Male'] > 0) & (df['prior_period_male'] > 0)), ((df['Male'] / df['prior_period_male'])-1), np.NaN)

# Round
df['diff_total'] = df['diff_total'].round(2)
df['diff_total'] = df['diff_total'].round(2)
df['diff_total'] = df['diff_total'].round(2)

# Check results
df.head(20)
# Out:
#    Country or Area                  City            City type  \
# 0          Albania                Durrës          City proper
# 1          Albania                TIRANA          City proper
# 2          Albania                TIRANA          City proper
# 3   American Samoa             PAGO PAGO          City proper
# 4          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 5          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 6          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 7          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 8          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 9          Andorra      ANDORRA LA VELLA  Urban agglomeration
# 10         Andorra      ANDORRA LA VELLA  Urban agglomeration
# 11         Andorra      ANDORRA LA VELLA  Urban agglomeration
# 12         Armenia    Gyumri (Leninakan)          City proper
# 13         Armenia    Gyumri (Leninakan)          City proper
# 14         Armenia    Gyumri (Leninakan)          City proper
# 15         Armenia    Gyumri (Leninakan)          City proper
# 16         Armenia    Gyumri (Leninakan)          City proper
# 17         Armenia    Gyumri (Leninakan)          City proper
# 18         Armenia    Gyumri (Leninakan)          City proper
# 19         Armenia  Vanadzoz (Kirovakan)          City proper
#
#                                Record Type  Year     Total    Female  \
# 0   Census - de jure - complete tabulation  2011  113249.0   56738.0
# 1   Census - de jure - complete tabulation  2011  418495.0  215256.0
# 2                      Estimate - de facto  2003  392863.0  198857.0
# 3   Census - de jure - complete tabulation  2000    4278.0    2192.0
# 4                       Estimate - de jure  2003   21245.0   10543.0
# 5                       Estimate - de jure  2005   23587.0   11718.0
# 6                       Estimate - de jure  2006   24211.0   11944.0
# 7                       Estimate - de jure  2007   24574.0   12148.0
# 8                       Estimate - de jure  2008   24632.0   12195.0
# 9                       Estimate - de jure  2009   24779.0   12240.0
# 10                      Estimate - de jure  2010   23505.0   11755.0
# 11                      Estimate - de jure  2011   22205.0   11149.0
# 12  Census - de jure - complete tabulation  2001  150917.0   80071.0
# 13  Census - de jure - complete tabulation  2011  121976.0   64844.0
# 14                      Estimate - de jure  2004  149200.0   78500.0
# 15                      Estimate - de jure  2006  148000.0   77458.0
# 16                      Estimate - de jure  2007  147350.0   76966.0
# 17                      Estimate - de jure  2008  146704.0   76448.0
# 18                      Estimate - de jure  2009  146355.0   75887.0
# 19  Census - de jure - complete tabulation  2001  107394.0   57110.0
#
#         Male                                                key  rank  \
# 0    56511.0  Albania | Durrës | City proper | Census - de j...     1
# 1   203239.0  Albania | TIRANA | City proper | Census - de j...     2
# 2   194006.0  Albania | TIRANA | City proper | Estimate - de...     3
# 3     2086.0  American Samoa | PAGO PAGO | City proper | Cen...     4
# 4    10702.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 5    11869.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 6    12267.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 7    12426.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 8    12437.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 9    12539.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 10   11750.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 11   11056.0  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
# 12   70846.0  Armenia | Gyumri (Leninakan) | City proper | C...     6
# 13   57132.0  Armenia | Gyumri (Leninakan) | City proper | C...     6
# 14   70700.0  Armenia | Gyumri (Leninakan) | City proper | E...     7
# 15   70542.0  Armenia | Gyumri (Leninakan) | City proper | E...     7
# 16   70384.0  Armenia | Gyumri (Leninakan) | City proper | E...     7
# 17   70256.0  Armenia | Gyumri (Leninakan) | City proper | E...     7
# 18   70468.0  Armenia | Gyumri (Leninakan) | City proper | E...     7
# 19   50284.0  Armenia | Vanadzoz (Kirovakan) | City proper |...     8
#
#     prior_period_total  prior_period_female  prior_period_male  prior_rank  \
# 0                  NaN                  NaN                NaN         NaN
# 1                  NaN                  NaN                NaN         1.0
# 2                  NaN                  NaN                NaN         2.0
# 3                  NaN                  NaN                NaN         3.0
# 4                  NaN                  NaN                NaN         4.0
# 5              21245.0              10543.0            10702.0         5.0
# 6              23587.0              11718.0            11869.0         5.0
# 7              24211.0              11944.0            12267.0         5.0
# 8              24574.0              12148.0            12426.0         5.0
# 9              24632.0              12195.0            12437.0         5.0
# 10             24779.0              12240.0            12539.0         5.0
# 11             23505.0              11755.0            11750.0         5.0
# 12                 NaN                  NaN                NaN         5.0
# 13            150917.0              80071.0            70846.0         6.0
# 14                 NaN                  NaN                NaN         6.0
# 15            149200.0              78500.0            70700.0         7.0
# 16            148000.0              77458.0            70542.0         7.0
# 17            147350.0              76966.0            70384.0         7.0
# 18            146704.0              76448.0            70256.0         7.0
# 19                 NaN                  NaN                NaN         7.0
#
#     diff_total  diff_female  diff_male
# 0          NaN          NaN        NaN
# 1          NaN          NaN        NaN
# 2          NaN          NaN        NaN
# 3          NaN          NaN        NaN
# 4          NaN          NaN        NaN
# 5         0.11     0.111448   0.109045
# 6         0.03     0.019287   0.033533
# 7         0.01     0.017080   0.012962
# 8         0.00     0.003869   0.000885
# 9         0.01     0.003690   0.008201
# 10       -0.05    -0.039624  -0.062924
# 11       -0.06    -0.051553  -0.059064
# 12         NaN          NaN        NaN
# 13       -0.19    -0.190169  -0.193575
# 14         NaN          NaN        NaN
# 15       -0.01    -0.013274  -0.002235
# 16       -0.00    -0.006352  -0.002240
# 17       -0.00    -0.006730  -0.001819
# 18       -0.00    -0.007338   0.003018
# 19         NaN          NaN        NaN

# %% [markdown]
# #### Create % Female and % Male

# %%
df['perc_male'] = df['Male'] / df['Total']
df['perc_female'] = df['Female'] / df['Total']

# %% [markdown]
# #### Tabulate information about the last Census

# %%
df_last_census_max_population = df.sort_values(by = ['Country or Area', 'City', 'Year', 'Total'], ascending = [True, True, False, False]).groupby(['Country or Area', 'City'], as_index=False).first()
df_last_census_max_population = df_last_census_max_population[['Country or Area', 'City', 'Year', 'Record Type', 'Total', 'diff_total']]
df_last_census_max_population.columns = ['Country or Area', 'City', 'Year Last Census', 'Record Type Last Census', 'Total Last Census', 'Diff Total Last Census']
df_last_census_max_population.head()
# Out:
#   Country or Area                City  Year Last Census  \
# 0         Albania              Durrës              2011
# 1         Albania              TIRANA              2011
# 2  American Samoa           PAGO PAGO              2000
# 3         Andorra    ANDORRA LA VELLA              2011
# 4         Armenia  Gyumri (Leninakan)              2011
#
#                   Record Type Last Census  Total Last Census  \
# 0  Census - de jure - complete tabulation           113249.0
# 1  Census - de jure - complete tabulation           418495.0
# 2  Census - de jure - complete tabulation             4278.0
# 3                      Estimate - de jure            22205.0
# 4  Census - de jure - complete tabulation           121976.0
#
#    Diff Total Last Census
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                   -0.06
# 4                   -0.19

# %%
df = pd.merge(df, df_last_census_max_population, on=['Country or Area', 'City'], how='left')

# %% [markdown]
# ### Flagging some outliers

# %%
aggregations = dict()
aggregations['key'] = 'count'
aggregations['Total'] = ['mean', 'std']

population = df.groupby(['Country or Area', 'City type', 'Record Type', 'Year'], as_index=False).agg(aggregations)
population = pd.DataFrame(population.to_records())
population.columns = ['index', 'Country or Area', 'City type', 'Record Type', 'Year', 'count', 'mean', 'std']
population = population.drop(['index'], axis=1)
population = population[population['count'] >= 10]

df_outliers = pd.merge(df, population, on=['Country or Area', 'City type', 'Record Type', 'Year'], how='left')
df_outliers['zscore'] = (df_outliers['Total'] - df_outliers['mean']) / df_outliers['std']
df_outliers['is_outlier_upper'] = np.where(df_outliers['zscore'] >= 3, 'YES', 'NO')
df_outliers['is_outlier_lower'] = np.where(df_outliers['zscore'] <= -1, 'YES', 'NO')

# %% [markdown]
# ### Country / City aggregation

# %%
aggregations = dict()
aggregations['Year'] = ['min', 'max', 'nunique', 'unique']
tabulation = df_outliers.groupby(['Country or Area', 'City'], as_index=False).agg(aggregations)
tabulation = pd.DataFrame(tabulation.to_records())
tabulation.columns = ['index', 'Country or Area', 'City', 'First Census', 'Last Census', 'Quantity of Census', 'Years of Census']
tabulation = tabulation.drop(['index'], axis = 1)
tabulation.head(5)
# Out:
#   Country or Area                City  First Census  Last Census  \
# 0         Albania              Durrës          2011         2011
# 1         Albania              TIRANA          2003         2011
# 2  American Samoa           PAGO PAGO          2000         2000
# 3         Andorra    ANDORRA LA VELLA          2003         2011
# 4         Armenia  Gyumri (Leninakan)          2001         2011
#
#    Quantity of Census                                   Years of Census
# 0                   1                                            [2011]
# 1                   2                                      [2011, 2003]
# 2                   1                                            [2000]
# 3                   8  [2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011]
# 4                   7        [2001, 2011, 2004, 2006, 2007, 2008, 2009]

# %%
df_city_aggr = pd.merge(df_outliers, tabulation, on=['Country or Area', 'City'], how='left')
df_city_aggr.head()
# Out:
#   Country or Area              City            City type  \
# 0         Albania            Durrës          City proper
# 1         Albania            TIRANA          City proper
# 2         Albania            TIRANA          City proper
# 3  American Samoa         PAGO PAGO          City proper
# 4         Andorra  ANDORRA LA VELLA  Urban agglomeration
#
#                               Record Type  Year     Total    Female      Male  \
# 0  Census - de jure - complete tabulation  2011  113249.0   56738.0   56511.0
# 1  Census - de jure - complete tabulation  2011  418495.0  215256.0  203239.0
# 2                     Estimate - de facto  2003  392863.0  198857.0  194006.0
# 3  Census - de jure - complete tabulation  2000    4278.0    2192.0    2086.0
# 4                      Estimate - de jure  2003   21245.0   10543.0   10702.0
#
#                                                  key  rank  \
# 0  Albania | Durrës | City proper | Census - de j...     1
# 1  Albania | TIRANA | City proper | Census - de j...     2
# 2  Albania | TIRANA | City proper | Estimate - de...     3
# 3  American Samoa | PAGO PAGO | City proper | Cen...     4
# 4  Andorra | ANDORRA LA VELLA | Urban agglomerati...     5
#
#                          ...                         count  mean  std  zscore  \
# 0                        ...                           NaN   NaN  NaN     NaN
# 1                        ...                           NaN   NaN  NaN     NaN
# 2                        ...                           NaN   NaN  NaN     NaN
# 3                        ...                           NaN   NaN  NaN     NaN
# 4                        ...                           NaN   NaN  NaN     NaN
#
#    is_outlier_upper  is_outlier_lower  First Census  Last Census  \
# 0                NO                NO          2011         2011
# 1                NO                NO          2003         2011
# 2                NO                NO          2003         2011
# 3                NO                NO          2000         2000
# 4                NO                NO          2003         2011
#
#    Quantity of Census                                   Years of Census
# 0                   1                                            [2011]
# 1                   2                                      [2011, 2003]
# 2                   2                                      [2011, 2003]
# 3                   1                                            [2000]
# 4                   8  [2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011]
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Exporting data

# %%
def implode (v):
    return "|".join([str(i) for i in v])

df_city_aggr['Years of Census'] = df_city_aggr['Years of Census'].apply(implode)
df_city_aggr[['Years of Census']].head(5)
# Out:
#                            Years of Census
# 0                                     2011
# 1                                2011|2003
# 2                                2011|2003
# 3                                     2000
# 4  2003|2005|2006|2007|2008|2009|2010|2011

# %%
df_city_aggr.to_csv('dataset_elsa.csv', encoding='utf_8', index=False)
